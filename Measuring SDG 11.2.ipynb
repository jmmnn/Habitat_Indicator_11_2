# %% [markdown]
# <div align="right">Python 2.7 Jupyter Notebook</div>
#
# # Rapid Estimation of the Sustainable Development Goal 11.2
#
#
# # "By 2030, provide access to safe, affordable, accessible and sustainable transport systems for all, improving road safety, notably by expanding public transport, with special attention to the needs of those in vulnerable situations, women, children, persons with disabilities and older persons "
#
# <br>

# %% [markdown]
# ## About this project
#
# > One of the internationally agreed indicators for this goal is:
#
# "11.2.1  Proportion of population that has convenient access to public transport, by sex, age and persons with disabilities"
#
#
# ### Data requirement:
#
# - Location of public transportation routes and stops
#
# - Population within 0.5 km from each stop.
#
#
# ### Potential data sources
#
# - Mobile telephone data provide by a mobile operator. It shuold be anonymized e.g. should not include telephone number or any individually identifiable information.
#
#
# ### Policy research question
#
# Can we use mobile telephone data for estimating the location of public-transportation "stops" as well as the population living within a 0.5 km radious?
#
#
# ## Methodology
#
# ### New data sources:
#
# - Map bus routes and stops with cellular data:
#
# https://www.technologyreview.com/s/514211/african-bus-routes-redrawn-using-cell-phone-data/
#
#
#
# - Map Population density based on cellular data:
#
# https://www.youtube.com/watch?v=qsUDH5dUnvY
# http://www.pnas.org/content/111/45/15888.full
#
#
#
# ### Datsources used for validation:
#
# - Bus route map obtained through GPS given to passengers in buses:
#
# http://www.digitalmatatus.com/intro_lite.html
#
#
# - Population density would be validated against the previous census.
#
#
# ## Expected Outcomes
# The outcome of the project is intended to be a documented methodology and open source code to compute this SDG indicator.
#
# It is expected that the methodology will continue to be refined and further developed for other indicators in an open and collaborative manner by academia, private sector, governments and the open source community.
#
#
# ## Limitations of this methodology
# This methodology currently does not fully address disaggregation of data eg. women, children, persons with disabilities, and older persons.
#
# ## Next steps
#
# Milestone 1: Project Sign off:
#
# Immediate steps:
#
# - Inform management of the outcome of the workshop
# - Formulate a proposal paper (validate the approach, including a business case)
#
#
# Parners:
#
# - Data partners: Mobile companies
# - Data experts: Global Pulse
# - Problem Solver: UN-Habitat
